# %% [markdown]
# # load benchmark

# %%
import Imoex as im
import Portfolio as pf

imoex = im.Imoex()
tgtPercentage = imoex.getIndex()
p = pf.Portfolio(tolerance=5000)
p.setTarget(tgtPercentage)

p.getTarget()
# Out:
#         percent     price        name
# ticker
# LKOH       0.16  6,919.00      ЛУКОЙЛ
# SBER       0.13    268.05    Сбербанк
# GAZP       0.12    140.40  ГАЗПРОМ ао
# TATN       0.07    643.50  Татнфт 3ао
# YDEX       0.04  4,040.00      ЯНДЕКС
# GMKN       0.04    115.30   ГМКНорНик
# TCSG       0.04  2,642.50  ТКСХолд ао
# NVTK       0.04  1,025.40  Новатэк ао
# PLZL       0.03 13,396.50       Полюс
# SNGS       0.03     25.02    Сургнфгз
# SNGSP      0.03     55.16  Сургнфгз-п
# SBERP      0.02    268.13  Сбербанк-п
# ROSN       0.02    511.00    Роснефть
# CHMF       0.02  1,286.20    СевСт-ао
# IRAO       0.01      3.81  ИнтерРАОао
# NLMK       0.01    144.82     НЛМК ао
# PIKK       0.01    654.90      ПИК ао
# RUAL       0.01     34.83    РУСАЛ ао
# TATNP      0.01    639.00  Татнфт 3ап
# MOEX       0.01    219.03    МосБиржа
# MAGN       0.01     45.13         ММК
# ALRS       0.01     55.24   АЛРОСА ао
# MTSS       0.01    206.75      МТС-ао
# RTKM       0.01     76.62  Ростел -ао
# AFLT       0.01     54.50    Аэрофлот
# VTBR       0.01     90.54      ВТБ ао
# POSI       0.01  2,683.20    iПозитив
# PHOR       0.01  5,400.00  ФосАгро ао
# CBOM       0.01      6.40      МКБ ао
# TRNFP      0.01  1,386.00  Транснф ап
# AFKS       0.01     16.43  Система ао
# VKCO       0.01    361.40  МКПАО "ВК"
# BSPB       0.01    394.85      БСП ао
# FLOT       0.00     99.29  Совкомфлот
# FEES       0.00      0.09     Россети
# ENPG       0.00    347.70  ЭН+ГРУП ао
# ASTR       0.00    567.35    Астра ао
# MSNG       0.00      2.45  +МосЭнерго
# SELG       0.00     58.05    Селигдар
# UPRO       0.00      1.74   Юнипро ао
# MTLR       0.00    123.35    Мечел ао
# HYDR       0.00      0.56    РусГидро
# LEAS       0.00    681.80    Европлан
# SMLT       0.00  1,953.00  Самолет ао
# MTLRP      0.00    127.35    Мечел ап

# %% [markdown]
# # load current portfolio

# %%
p.setCurrent('CurrentV.csv')
p.getCurrent()
# Out:
#               qty     price   lotSize        date  \
# ticker
# @RUB   403,929.00      0.00      0.00           0
# AFKS       300.00     16.17    100.00  2024-09-26
# AFLT       120.00     53.22     10.00  2024-09-26
# AGRO         0.00  1,192.40      1.00  2024-09-26
# ALRS       150.00     54.64     10.00  2024-09-26
# ASTR         5.00    552.05      1.00  2024-09-26
# BSPB        10.00    389.67     10.00  2024-09-26
# CBOM       800.00      6.30    100.00  2024-09-26
# CHMF        12.00  1,271.00      1.00  2024-09-26
# ENPG         5.00    345.55      1.00  2024-09-26
# FEES    30,001.00      0.09 10,000.00  2024-09-26
# FIVE         0.00  2,798.00      1.00  2024-09-26
# FLOT        40.00     97.80     10.00  2024-09-26
# GAZP       730.00    137.35     10.00  2024-09-26
# GLTR         0.00    486.05      1.00  2024-09-26
# GMKN       300.00    115.48     10.00  2024-09-26
# HYDR         0.00      0.54  1,000.00  2024-09-26
# IRAO     3,100.00      3.83    100.00  2024-09-26
# LEAS         0.00    679.70      1.00  2024-09-26
# LKOH        20.00  6,890.00      1.00  2024-09-26
# MAGN       210.00     44.91     10.00  2024-09-26
# MGNT         0.00  5,789.50      1.00  2024-09-26
# MOEX        50.00    213.21     10.00  2024-09-26
# MSNG         0.00      2.48  1,000.00  2024-09-26
# MTLR         0.00    121.23      1.00  2024-09-26
# MTLRP        0.00    125.15     10.00  2024-09-26
# MTSS        40.00    206.80     10.00  2024-09-26
# NLMK        80.00    142.48     10.00  2024-09-26
# NVTK        29.00  1,015.60      1.00  2024-09-26
# OZON         0.00  3,259.50      1.00  2024-09-26
# PHOR         1.00  5,432.00      1.00  2024-09-26
# PIKK        17.00    634.10      1.00  2024-09-26
# PLZL         2.00 13,528.00      1.00  2024-09-26
# POSI         2.00  2,627.00      1.00  2024-09-26
# ROSN        36.00    512.70      1.00  2024-09-26
# RTKM       100.00     80.48     10.00  2024-09-26
# RUAL       300.00     34.49     10.00  2024-09-26
# SBER       400.00    267.88     10.00  2024-09-26
# SBERP       80.00    267.63     10.00  2024-09-26
# SELG         0.00     58.00     10.00  2024-09-26
# SMLT         0.00  1,914.00      1.00  2024-09-26
# SNGS     1,000.00     24.90    100.00  2024-09-26
# SNGSP      430.00     54.23     10.00  2024-09-26
# TATN        87.00    639.50      1.00  2024-09-26
# TATNP       16.00    635.10      1.00  2024-09-26
# TCSG        12.00  2,614.00      1.00  2024-09-26
# TRNFP        4.00  1,391.50      1.00  2024-09-26
# UPRO         0.00      1.73  1,000.00  2024-09-26
# VKCO        13.00    363.00      1.00  2024-09-26
# VTBR        71.00     90.76      1.00  2024-09-26
# YDEX         0.00  4,001.50      1.00  2024-09-26
#
#                                   name  percent      value
# ticker
# @RUB                                 0     0.00       0.00
# AFKS                       AFK Sistema     0.00   4,850.10
# AFLT                          Aeroflot     0.01   6,386.40
# AGRO          GDR ROS AGRO PLC ORD SHS     0.00       0.00
# ALRS                         ALROSA ao     0.01   8,196.00
# ASTR                       Astra Group     0.00   2,760.25
# BSPB                               BSP     0.00   3,896.70
# CBOM                            MKB ao     0.00   5,037.60
# CHMF                    Severstal - ao     0.01  15,252.00
# ENPG           EN+ GROUP IPJSC ORD SHS     0.00   1,727.75
# FEES                       FGC ROSSETI     0.00   2,557.89
# FIVE    GDR X5 RetailGroup N.V.ORD SHS     0.00       0.00
# FLOT                        Sovcomflot     0.00   3,912.00
# GAZP                           Gazprom     0.08 100,265.50
# GLTR     GDR Globaltrans Inves ORD SHS     0.00       0.00
# GMKN                     NorNickel GMK     0.03  34,644.00
# HYDR                          RusGidro     0.00       0.00
# IRAO                      Inter RAO ao     0.01  11,879.20
# LEAS                          Europlan     0.00       0.00
# LKOH                            LUKOIL     0.12 137,800.00
# MAGN                               MMK     0.01   9,432.15
# MGNT                            Magnit     0.00       0.00
# MOEX                    MoscowExchange     0.01  10,660.50
# MSNG                           MosEnrg     0.00       0.00
# MTLR                            Mechel     0.00       0.00
# MTLRP                     Mechel pref.     0.00       0.00
# MTSS                               MTS     0.01   8,272.00
# NLMK                           NLMK ao     0.01  11,398.40
# NVTK                           NOVATEK     0.02  29,452.40
# OZON     ADS Ozon Holdings PLC ORD SHS     0.00       0.00
# PHOR                       PhosAgro ao     0.00   5,432.00
# PIKK                            PIK SZ     0.01  10,779.70
# PLZL                             Polus     0.02  27,056.00
# POSI               PJSC Positive Group     0.00   5,254.00
# ROSN                           Rosneft     0.02  18,457.20
# RTKM                        Rostelecom     0.01   8,048.00
# RUAL                          RUSAL ao     0.01  10,348.50
# SBER                          Sberbank     0.09 107,152.00
# SBERP                  Sberbank (pref)     0.02  21,410.40
# SELG                          Seligdar     0.00       0.00
# SMLT                           Samolet     0.00       0.00
# SNGS                            Surgut     0.02  24,900.00
# SNGSP                      Surgut-pref     0.02  23,318.90
# TATN                         Tatneft-3     0.05  55,636.50
# TATNP                   Tatneft (pref)     0.01  10,161.60
# TCSG                 IPJSC TCS Holding     0.03  31,368.00
# TRNFP                 Transneft (pref)     0.00   5,566.00
# UPRO                     Unipro PAO ao     0.00       0.00
# VKCO    VK International Public JS Com     0.00   4,719.00
# VTBR                               VTB     0.01   6,443.96
# YDEX                            YANDEX     0.00       0.00

# %% [markdown]
# # rebalance value

# %%
p.getStocksValue() + p.getCashValue()
# Out:
# np.float64(1188361.5952599999)

# %%
c = p.rebalance()
c
# Out:
# sum valueTgt
# 403928.99999999994
# sum valueTgt2
# 403928.9999999999
# sum chg val
# -233563.60000000003
#            nameTgt  chgQty   chgValue
# ticker
# YDEX        ЯНДЕКС    5.36  21,455.93
# PIKK        ПИК ао   -6.38  -4,048.43
# CHMF      СевСт-ао   -4.76  -6,049.09
# ROSN      Роснефть  -14.46  -7,413.70
# SNGSP   Сургнфгз-п -165.27  -8,962.36
# SBERP   Сбербанк-п  -33.82  -9,052.20
# SNGS      Сургнфгз -417.10 -10,385.69
# NVTK    Новатэк ао  -10.98 -11,151.75
# PLZL         Полюс   -0.89 -12,068.40
# TCSG    ТКСХолд ао   -4.68 -12,225.94
# GMKN     ГМКНорНик -118.30 -13,661.36
# TATN    Татнфт 3ао  -34.78 -22,243.07
# GAZP    ГАЗПРОМ ао -278.59 -38,264.16
# SBER      Сбербанк -160.89 -43,099.73
# LKOH        ЛУКОЙЛ   -8.18 -56,393.66

# %% [markdown]
# # after rebalance

# %%
c1 = p.getCashValue()
a1 = p.getStocksValue()

p.applyChanges(c)
c2 = p.getCashValue()
a2 = p.getStocksValue()

# output results
print(f'before cash {c1:,.0f} stocks {a1:,.0f} total {(a1+c1):,.0f}')
print(f'after cash {c2:,.0f} stocks {a2:,.0f} total {(a2+c2):,.0f}')
p.getCurrent()
# Out:
# before cash 403,929 stocks 784,433 total 1,188,362
# after cash 637,493 stocks 550,869 total 1,188,362
#               qty     price   lotSize        date  \
# ticker
# LKOH        11.82  6,890.00      1.00  2024-09-26
# SBER       239.11    267.88     10.00  2024-09-26
# GAZP       451.41    137.35     10.00  2024-09-26
# TATN        52.22    639.50      1.00  2024-09-26
# YDEX         5.36  4,001.50      1.00  2024-09-26
# GMKN       181.70    115.48     10.00  2024-09-26
# TCSG         7.32  2,614.00      1.00  2024-09-26
# NVTK        18.02  1,015.60      1.00  2024-09-26
# PLZL         1.11 13,528.00      1.00  2024-09-26
# SNGS       582.90     24.90    100.00  2024-09-26
# SNGSP      264.73     54.23     10.00  2024-09-26
# SBERP       46.18    267.63     10.00  2024-09-26
# IRAO     3,100.00      3.83    100.00  2024-09-26
# NLMK        80.00    142.48     10.00  2024-09-26
# ROSN        21.54    512.70      1.00  2024-09-26
# MOEX        50.00    213.21     10.00  2024-09-26
# RUAL       300.00     34.49     10.00  2024-09-26
# TATNP       16.00    635.10      1.00  2024-09-26
# MAGN       210.00     44.91     10.00  2024-09-26
# CHMF         7.24  1,271.00      1.00  2024-09-26
# MTSS        40.00    206.80     10.00  2024-09-26
# ALRS       150.00     54.64     10.00  2024-09-26
# RTKM       100.00     80.48     10.00  2024-09-26
# PIKK        10.62    634.10      1.00  2024-09-26
# VTBR        71.00     90.76      1.00  2024-09-26
# AFLT       120.00     53.22     10.00  2024-09-26
# TRNFP        4.00  1,391.50      1.00  2024-09-26
# PHOR         1.00  5,432.00      1.00  2024-09-26
# POSI         2.00  2,627.00      1.00  2024-09-26
# CBOM       800.00      6.30    100.00  2024-09-26
# AFKS       300.00     16.17    100.00  2024-09-26
# VKCO        13.00    363.00      1.00  2024-09-26
# FLOT        40.00     97.80     10.00  2024-09-26
# BSPB        10.00    389.67     10.00  2024-09-26
# ASTR         5.00    552.05      1.00  2024-09-26
# FEES    30,001.00      0.09 10,000.00  2024-09-26
# ENPG         5.00    345.55      1.00  2024-09-26
# LEAS         0.00    679.70      1.00  2024-09-26
# HYDR         0.00      0.54  1,000.00  2024-09-26
# AGRO         0.00  1,192.40      1.00  2024-09-26
# @RUB   403,929.00      0.00      0.00           0
# FIVE         0.00  2,798.00      1.00  2024-09-26
# GLTR         0.00    486.05      1.00  2024-09-26
# OZON         0.00  3,259.50      1.00  2024-09-26
# MSNG         0.00      2.48  1,000.00  2024-09-26
# MTLR         0.00    121.23      1.00  2024-09-26
# MTLRP        0.00    125.15     10.00  2024-09-26
# MGNT         0.00  5,789.50      1.00  2024-09-26
# SMLT         0.00  1,914.00      1.00  2024-09-26
# SELG         0.00     58.00     10.00  2024-09-26
# UPRO         0.00      1.73  1,000.00  2024-09-26
#
#                                   name  percent     value     nameTgt  chgQty  \
# ticker
# LKOH                            LUKOIL     0.07 81,406.34      ЛУКОЙЛ   -8.18
# SBER                          Sberbank     0.05 64,052.27    Сбербанк -160.89
# GAZP                           Gazprom     0.05 62,001.34  ГАЗПРОМ ао -278.59
# TATN                         Tatneft-3     0.03 33,393.43  Татнфт 3ао  -34.78
# YDEX                            YANDEX     0.02 21,455.93      ЯНДЕКС    5.36
# GMKN                     NorNickel GMK     0.02 20,982.64   ГМКНорНик -118.30
# TCSG                 IPJSC TCS Holding     0.02 19,142.06  ТКСХолд ао   -4.68
# NVTK                           NOVATEK     0.02 18,300.65  Новатэк ао  -10.98
# PLZL                             Polus     0.01 14,987.60       Полюс   -0.89
# SNGS                            Surgut     0.01 14,514.31    Сургнфгз -417.10
# SNGSP                      Surgut-pref     0.01 14,356.54  Сургнфгз-п -165.27
# SBERP                  Sberbank (pref)     0.01 12,358.20  Сбербанк-п  -33.82
# IRAO                      Inter RAO ao     0.01 11,879.20           0    0.00
# NLMK                           NLMK ao     0.01 11,398.40           0    0.00
# ROSN                           Rosneft     0.01 11,043.50    Роснефть  -14.46
# MOEX                    MoscowExchange     0.01 10,660.50           0    0.00
# RUAL                          RUSAL ao     0.01 10,348.50           0    0.00
# TATNP                   Tatneft (pref)     0.01 10,161.60           0    0.00
# MAGN                               MMK     0.01  9,432.15           0    0.00
# CHMF                    Severstal - ao     0.01  9,202.91    СевСт-ао   -4.76
# MTSS                               MTS     0.01  8,272.00           0    0.00
# ALRS                         ALROSA ao     0.01  8,196.00           0    0.00
# RTKM                        Rostelecom     0.01  8,048.00           0    0.00
# PIKK                            PIK SZ     0.01  6,731.27      ПИК ао   -6.38
# VTBR                               VTB     0.01  6,443.96           0    0.00
# AFLT                          Aeroflot     0.01  6,386.40           0    0.00
# TRNFP                 Transneft (pref)     0.00  5,566.00           0    0.00
# PHOR                       PhosAgro ao     0.00  5,432.00           0    0.00
# POSI               PJSC Positive Group     0.00  5,254.00           0    0.00
# CBOM                            MKB ao     0.00  5,037.60           0    0.00
# AFKS                       AFK Sistema     0.00  4,850.10           0    0.00
# VKCO    VK International Public JS Com     0.00  4,719.00           0    0.00
# FLOT                        Sovcomflot     0.00  3,912.00           0    0.00
# BSPB                               BSP     0.00  3,896.70           0    0.00
# ASTR                       Astra Group     0.00  2,760.25           0    0.00
# FEES                       FGC ROSSETI     0.00  2,557.89           0    0.00
# ENPG           EN+ GROUP IPJSC ORD SHS     0.00  1,727.75           0    0.00
# LEAS                          Europlan     0.00      0.00           0    0.00
# HYDR                          RusGidro     0.00      0.00           0    0.00
# AGRO          GDR ROS AGRO PLC ORD SHS     0.00      0.00           0    0.00
# @RUB                                 0     0.00      0.00           0    0.00
# FIVE    GDR X5 RetailGroup N.V.ORD SHS     0.00      0.00           0    0.00
# GLTR     GDR Globaltrans Inves ORD SHS     0.00      0.00           0    0.00
# OZON     ADS Ozon Holdings PLC ORD SHS     0.00      0.00           0    0.00
# MSNG                           MosEnrg     0.00      0.00           0    0.00
# MTLR                            Mechel     0.00      0.00           0    0.00
# MTLRP                     Mechel pref.     0.00      0.00           0    0.00
# MGNT                            Magnit     0.00      0.00           0    0.00
# SMLT                           Samolet     0.00      0.00           0    0.00
# SELG                          Seligdar     0.00      0.00           0    0.00
# UPRO                     Unipro PAO ao     0.00      0.00           0    0.00
#
#          chgValue
# ticker
# LKOH   -56,393.66
# SBER   -43,099.73
# GAZP   -38,264.16
# TATN   -22,243.07
# YDEX    21,455.93
# GMKN   -13,661.36
# TCSG   -12,225.94
# NVTK   -11,151.75
# PLZL   -12,068.40
# SNGS   -10,385.69
# SNGSP   -8,962.36
# SBERP   -9,052.20
# IRAO         0.00
# NLMK         0.00
# ROSN    -7,413.70
# MOEX         0.00
# RUAL         0.00
# TATNP        0.00
# MAGN         0.00
# CHMF    -6,049.09
# MTSS         0.00
# ALRS         0.00
# RTKM         0.00
# PIKK    -4,048.43
# VTBR         0.00
# AFLT         0.00
# TRNFP        0.00
# PHOR         0.00
# POSI         0.00
# CBOM         0.00
# AFKS         0.00
# VKCO         0.00
# FLOT         0.00
# BSPB         0.00
# ASTR         0.00
# FEES         0.00
# ENPG         0.00
# LEAS         0.00
# HYDR         0.00
# AGRO         0.00
# @RUB         0.00
# FIVE         0.00
# GLTR         0.00
# OZON         0.00
# MSNG         0.00
# MTLR         0.00
# MTLRP        0.00
# MGNT         0.00
# SMLT         0.00
# SELG         0.00
# UPRO         0.00
